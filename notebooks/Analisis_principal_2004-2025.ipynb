# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
rutas = ["datos_procesados_04-11.parquet","datos_procesados_12-18.parquet","datos_procesados_19-25.parquet"]

lista_dfs = []

for ruta in rutas:
    lista_dfs.append(pd.read_parquet(f"../data/{ruta}"))

# %%
for df in lista_dfs:
    print(df.columns)
# Out:
# Index(['id_estudiante', 'id_colegio_rbd', 'dependencia_colegio',
#        'rama_educacional', 'situacion_egreso', 'cod_region', 'cod_comuna',
#        'puntaje_lectora', 'puntaje_m1', 'puntaje_historia', 'puntaje_ciencias',
#        'tipo_ciencia', 'promedio_notas', 'puntaje_nem', 'year_proceso'],
#       dtype='object')
# Index(['id_estudiante', 'id_colegio_rbd', 'dependencia_colegio',
#        'rama_educacional', 'situacion_egreso', 'cod_region', 'cod_comuna',
#        'promedio_notas', 'puntaje_nem', 'puntaje_lectora', 'puntaje_m1',
#        'puntaje_historia', 'puntaje_ciencias', 'year_proceso',
#        'puntaje_ranking'],
#       dtype='object')
# Index(['id_estudiante', 'id_colegio_rbd', 'year_proceso',
#        'dependencia_colegio', 'situacion_egreso', 'rama_educacional',
#        'cod_region', 'cod_comuna', 'promedio_notas', 'puntaje_nem',
#        'puntaje_ranking', 'puntaje_lectora', 'puntaje_m1', 'puntaje_historia',
#        'puntaje_ciencias', 'tipo_ciencia', 'puntaje_m2'],
#       dtype='object')

# %%
mapa_renombre = {
        'ID_aux': 'id_estudiante',
        'RBD': 'id_colegio_rbd',
        'GRUPO_DEPENDENCIA': 'dependencia_colegio',
        'RAMA_EDUCACIONAL': 'rama_educacional',
        'SITUACION_EGRESO': 'situacion_egreso',
        'CODIGO_REGION': 'cod_region',
        'CODIGO_COMUNA': 'cod_comuna',
        'PROMEDIO_NOTAS': 'promedio_notas',
        'PTJE_NEM': 'puntaje_nem',
        'PTJE_RANKING': 'puntaje_ranking',
        'LENG_ACTUAL': 'puntaje_lectora',
        'CLEC_ACTUAL': 'puntaje_lectora',
        'CLEC_REG_ACTUAL': 'puntaje_lectora',

        'MATE_ACTUAL': 'puntaje_m1',
        'MATE1_REG_ACTUAL': 'puntaje_m1',

        'MATE2_REG_ACTUAL': 'puntaje_m2',

        'HCSO_ACTUAL': 'puntaje_historia',
        'HCSOC_REG_ACTUAL': 'puntaje_historia',

        'CIEN_ACTUAL': 'puntaje_ciencias',
        'CIEN_REG_ACTUAL': 'puntaje_ciencias',
        'MODULO_ACTUAL': 'tipo_ciencia',
        'MODULO_REG_ACTUAL': 'tipo_ciencia',
        'YEAR_PROCESO': 'year_proceso'
    }

    # Aplicamos el nuevo nombre de las columnas
lista_dfs[0].rename(columns=mapa_renombre, inplace=True)

# %%
mapa_dependencia = {
    1.0: 'Particular Pagado',
    2.0: 'Particular Subvencionado',
    3.0: 'Municipal',
    4.0: 'Servicio Local de Educación'
}

lista_dfs[0]['dependencia_colegio'] = lista_dfs[0]['dependencia_colegio'].map(mapa_dependencia)

# %%
lista_dfs[0]["promedio_notas"] = lista_dfs[0]["promedio_notas"] / 10

# %%
df = pd.concat(lista_dfs).reset_index(drop=True)

# %%
mapa_situacion = {
    1.0: "Act:Nacional-Regular",
    2.0: "Act:Nacional-V_Notas",
    3.0: "Act:Extranjero",
    4.0: "Act:Extranjero", # No nos vamos a meter temas tan especificos en cuanto la situacion de alumnos extranjeros
    5.0: "Ant:Nacional-Regular",
    6.0: "Ant:Nacional-V_Notas",
    7.0: "Ant:Extranjero",
    8.0: "Ant:Extranjero",
}

mapa_rama = {
    "H1": "CH diurno",
    "H2": "CH nocturno",
    "H3": "CH - validación de estudios",
    "H4": "CH - reconocimiento de estudios",
    "T1": "TP comercial",
    "T2": "TP industrial",
    "T3": "TP servicios y técnica",
    "T4": "TP agrícola",
    "T5": "TP marítima",
}

df["situacion_egreso"] = df["situacion_egreso"].map(mapa_situacion)
df["rama_educacional"] = df["rama_educacional"].map(mapa_rama)


df
# Out:
#             id_estudiante  id_colegio_rbd          dependencia_colegio  \
# 0         id_001160071115             NaN                    Municipal
# 1        id_0016900171627             NaN                    Municipal
# 2        id_0016900571641             NaN                    Municipal
# 3        id_0028900472899             NaN                    Municipal
# 4         id_004500078456             NaN     Particular Subvencionado
# ...                   ...             ...                          ...
# 5455232  id_5995599440825          9986.0                    Municipal
# 5455233  id_4895488246247             NaN                          NaN
# 5455234  id_9866988747313          9140.0     Particular Subvencionado
# 5455235  id_5866598447255          2733.0                    Municipal
# 5455236  id_7666786545377           125.0  Servicio Local de Educación
#
#                         rama_educacional      situacion_egreso  cod_region  \
# 0                           TP comercial  Act:Nacional-Regular         1.0
# 1                            CH nocturno  Ant:Nacional-Regular         3.0
# 2                           TP comercial  Ant:Nacional-Regular         2.0
# 3                              CH diurno  Act:Nacional-Regular         8.0
# 4                            CH nocturno  Act:Nacional-Regular        10.0
# ...                                  ...                   ...         ...
# 5455232                     TP comercial  Act:Nacional-Regular        13.0
# 5455233  CH - reconocimiento de estudios        Act:Extranjero         NaN
# 5455234                        CH diurno  Ant:Nacional-Regular        13.0
# 5455235                        CH diurno  Ant:Nacional-Regular         7.0
# 5455236                        CH diurno  Ant:Nacional-Regular         1.0
#
#          cod_comuna  puntaje_lectora  puntaje_m1  puntaje_historia  \
# 0             201.0            469.0       457.0             437.0
# 1             240.0            492.0       457.0             513.0
# 2             225.0            391.0       442.0              <NA>
# 3             415.0            353.0       487.0             402.0
# 4             510.0            430.0       425.0             451.0
# ...             ...              ...         ...               ...
# 5455232     13126.0             <NA>        <NA>              <NA>
# 5455233         NaN            605.0       700.0             542.0
# 5455234     13122.0            746.0       589.0              <NA>
# 5455235      7301.0             <NA>        <NA>              <NA>
# 5455236      1101.0            596.0       710.0              <NA>
#
#          puntaje_ciencias tipo_ciencia  promedio_notas  puntaje_nem  \
# 0                   426.0         None            6.30        682.0
# 1                    <NA>         None            5.30        481.0
# 2                   396.0         None            4.80        376.0
# 3                    <NA>         None            4.80        373.0
# 4                    <NA>         None            5.40        501.0
# ...                   ...          ...             ...          ...
# 5455232              <NA>          NaN             NaN          NaN
# 5455233             502.0          BIO             NaN          NaN
# 5455234             665.0          BIO            6.28        793.0
# 5455235              <NA>          NaN            5.68        622.0
# 5455236              <NA>          NaN            5.38        536.0
#
#          year_proceso  puntaje_ranking  puntaje_m2
# 0                2004              NaN        <NA>
# 1                2004              NaN        <NA>
# 2                2004              NaN        <NA>
# 3                2004              NaN        <NA>
# 4                2004              NaN        <NA>
# ...               ...              ...         ...
# 5455232          2025              NaN        <NA>
# 5455233          2025              NaN        <NA>
# 5455234          2025            856.0         362
# 5455235          2025            631.0        <NA>
# 5455236          2025            536.0         362
#
# [5455237 rows x 17 columns]

# %%
psu = [x for x in range(2004, 2021)]
pdt = [2021, 2022]
paes = [x for x in range(2023,2026)]

df_PSU = df[df["year_proceso"].isin(psu)]
df_PDT = df[df["year_proceso"].isin(pdt)]
df_PAES = df[df["year_proceso"].isin(paes)]

display(df_PSU)
display(df_PDT)
display(df_PAES)
# Out:
#             id_estudiante  id_colegio_rbd       dependencia_colegio  \
# 0         id_001160071115             NaN                 Municipal
# 1        id_0016900171627             NaN                 Municipal
# 2        id_0016900571641             NaN                 Municipal
# 3        id_0028900472899             NaN                 Municipal
# 4         id_004500078456             NaN  Particular Subvencionado
# ...                   ...             ...                       ...
# 4050777  id_9999599479904         24482.0  Particular Subvencionado
# 4050778  id_9999599479967          8618.0  Particular Subvencionado
# 4050779  id_9999599479973         20316.0  Particular Subvencionado
# 4050780  id_9999599479977         14373.0  Particular Subvencionado
# 4050781  id_9999599779976           574.0  Particular Subvencionado
#
#         rama_educacional      situacion_egreso  cod_region  cod_comuna  \
# 0           TP comercial  Act:Nacional-Regular         1.0       201.0
# 1            CH nocturno  Ant:Nacional-Regular         3.0       240.0
# 2           TP comercial  Ant:Nacional-Regular         2.0       225.0
# 3              CH diurno  Act:Nacional-Regular         8.0       415.0
# 4            CH nocturno  Act:Nacional-Regular        10.0       510.0
# ...                  ...                   ...         ...         ...
# 4050777    TP industrial  Act:Nacional-Regular        13.0     13128.0
# 4050778        CH diurno  Act:Nacional-Regular        13.0     13101.0
# 4050779      CH nocturno  Act:Nacional-Regular        16.0     16101.0
# 4050780        CH diurno  Act:Nacional-Regular         5.0      5601.0
# 4050781    TP industrial  Act:Nacional-Regular         4.0      4101.0
#
#          puntaje_lectora  puntaje_m1  puntaje_historia  puntaje_ciencias  \
# 0                  469.0       457.0             437.0             426.0
# 1                  492.0       457.0             513.0              <NA>
# 2                  391.0       442.0              <NA>             396.0
# 3                  353.0       487.0             402.0              <NA>
# 4                  430.0       425.0             451.0              <NA>
# ...                  ...         ...               ...               ...
# 4050777            427.0       498.0             498.0             389.0
# 4050778            559.0       549.0              <NA>             542.0
# 4050779            407.0       415.0             477.0             446.0
# 4050780            380.0       332.0             451.0              <NA>
# 4050781            597.0       506.0             597.0              <NA>
#
#         tipo_ciencia  promedio_notas  puntaje_nem  year_proceso  \
# 0               None            6.30        682.0          2004
# 1               None            5.30        481.0          2004
# 2               None            4.80        376.0          2004
# 3               None            4.80        373.0          2004
# 4               None            5.40        501.0          2004
# ...              ...             ...          ...           ...
# 4050777          TEC            5.13        438.0          2020
# 4050778          QUI            5.80        580.0          2020
# 4050779          QUI            5.30        477.0          2020
# 4050780          NaN            5.20        451.0          2020
# 4050781          NaN            5.48        515.0          2020
#
#          puntaje_ranking  puntaje_m2
# 0                    NaN        <NA>
# 1                    NaN        <NA>
# 2                    NaN        <NA>
# 3                    NaN        <NA>
# 4                    NaN        <NA>
# ...                  ...         ...
# 4050777            438.0        <NA>
# 4050778            593.0        <NA>
# 4050779            477.0        <NA>
# 4050780            451.0        <NA>
# 4050781            515.0        <NA>
#
# [4050782 rows x 17 columns]
#             id_estudiante  id_colegio_rbd          dependencia_colegio  \
# 4050782  id_0000900070018         25418.0     Particular Subvencionado
# 4050783  id_0000900470042         25121.0     Particular Subvencionado
# 4050784  id_0000900670095         12730.0     Particular Subvencionado
# 4050785  id_0000900870002          4534.0                    Municipal
# 4050786  id_0001900170136          9534.0     Particular Subvencionado
# ...                   ...             ...                          ...
# 4543786  id_9999599979969          6253.0     Particular Subvencionado
# 4543787  id_9999599979970          6163.0                    Municipal
# 4543788  id_9999599979971          6163.0                    Municipal
# 4543789  id_9999599979986          6398.0  Servicio Local de Educación
# 4543790  id_9999599979998          9332.0     Particular Subvencionado
#
#                rama_educacional      situacion_egreso  cod_region  cod_comuna  \
# 4050782  TP servicios y técnica  Ant:Nacional-Regular        13.0     13401.0
# 4050783               CH diurno  Ant:Nacional-Regular        13.0     13301.0
# 4050784           TP industrial  Act:Nacional-Regular         1.0      1107.0
# 4050785            TP comercial  Ant:Nacional-Regular         8.0      8101.0
# 4050786               CH diurno  Ant:Nacional-Regular        13.0     13110.0
# ...                         ...                   ...         ...         ...
# 4543786               CH diurno  Act:Nacional-Regular         9.0      9114.0
# 4543787            TP comercial  Ant:Nacional-Regular         9.0      9105.0
# 4543788  TP servicios y técnica  Ant:Nacional-Regular         9.0      9105.0
# 4543789               CH diurno  Act:Nacional-Regular         9.0      9117.0
# 4543790               CH diurno  Act:Nacional-Regular        13.0     13110.0
#
#          puntaje_lectora  puntaje_m1  puntaje_historia  puntaje_ciencias  \
# 4050782            693.0       509.0             716.0             617.0
# 4050783            505.0       419.0             505.0              <NA>
# 4050784            214.0       405.0             360.0              <NA>
# 4050785            495.0       302.0              <NA>             365.0
# 4050786            764.0       614.0              <NA>             686.0
# ...                  ...         ...               ...               ...
# 4543786            600.0       555.0             538.0             569.0
# 4543787            507.0       310.0              <NA>             503.0
# 4543788            463.0       434.0              <NA>             455.0
# 4543789            235.0       278.0             350.0             314.0
# 4543790            279.0       409.0             405.0              <NA>
#
#         tipo_ciencia  promedio_notas  puntaje_nem  year_proceso  \
# 4050782          TEC            6.00        625.0          2021
# 4050783          NaN            5.35        483.0          2021
# 4050784          NaN            5.07        421.0          2021
# 4050785          TEC            5.60        539.0          2021
# 4050786          QUI            6.30        689.0          2021
# ...              ...             ...          ...           ...
# 4543786          BIO            5.63        545.0          2022
# 4543787          BIO            5.28        468.0          2022
# 4543788          TEC            6.30        692.0          2022
# 4543789          BIO            4.85        363.0          2022
# 4543790          NaN            5.25        459.0          2022
#
#          puntaje_ranking  puntaje_m2
# 4050782            713.0        <NA>
# 4050783            484.0        <NA>
# 4050784            421.0        <NA>
# 4050785            539.0        <NA>
# 4050786            757.0        <NA>
# ...                  ...         ...
# 4543786            548.0        <NA>
# 4543787            469.0        <NA>
# 4543788            813.0        <NA>
# 4543789            363.0        <NA>
# 4543790            459.0        <NA>
#
# [493009 rows x 17 columns]
#             id_estudiante  id_colegio_rbd          dependencia_colegio  \
# 4543791  id_0000900170003         10584.0                    Municipal
# 4543792  id_0000900470024         10250.0                    Municipal
# 4543793  id_0000900670068         12667.0     Particular Subvencionado
# 4543794  id_0001900070103          7006.0     Particular Subvencionado
# 4543795  id_0001900070149          6752.0                    Municipal
# ...                   ...             ...                          ...
# 5455232  id_5995599440825          9986.0                    Municipal
# 5455233  id_4895488246247             NaN                          NaN
# 5455234  id_9866988747313          9140.0     Particular Subvencionado
# 5455235  id_5866598447255          2733.0                    Municipal
# 5455236  id_7666786545377           125.0  Servicio Local de Educación
#
#                         rama_educacional      situacion_egreso  cod_region  \
# 4543791                      CH nocturno  Ant:Nacional-Regular        13.0
# 4543792                      CH nocturno  Act:Nacional-Regular        13.0
# 4543793                        CH diurno  Ant:Nacional-Regular         1.0
# 4543794                        CH diurno  Ant:Nacional-Regular        14.0
# 4543795           TP servicios y técnica  Ant:Nacional-Regular        14.0
# ...                                  ...                   ...         ...
# 5455232                     TP comercial  Act:Nacional-Regular        13.0
# 5455233  CH - reconocimiento de estudios        Act:Extranjero         NaN
# 5455234                        CH diurno  Ant:Nacional-Regular        13.0
# 5455235                        CH diurno  Ant:Nacional-Regular         7.0
# 5455236                        CH diurno  Ant:Nacional-Regular         1.0
#
#          cod_comuna  puntaje_lectora  puntaje_m1  puntaje_historia  \
# 4543791     13401.0             <NA>       402.0             423.0
# 4543792     13107.0            475.0        <NA>              <NA>
# 4543793      1101.0            536.0       413.0             489.0
# 4543794     14202.0            589.0       437.0              <NA>
# 4543795     14101.0             <NA>        <NA>              <NA>
# ...             ...              ...         ...               ...
# 5455232     13126.0             <NA>        <NA>              <NA>
# 5455233         NaN            605.0       700.0             542.0
# 5455234     13122.0            746.0       589.0              <NA>
# 5455235      7301.0             <NA>        <NA>              <NA>
# 5455236      1101.0            596.0       710.0              <NA>
#
#          puntaje_ciencias tipo_ciencia  promedio_notas  puntaje_nem  \
# 4543791              <NA>          NaN            5.03        429.0
# 4543792              <NA>          NaN            5.90        689.0
# 4543793              <NA>          NaN            5.00        415.0
# 4543794             478.0          BIO            5.60        599.0
# 4543795              <NA>          NaN            5.28        506.0
# ...                   ...          ...             ...          ...
# 5455232              <NA>          NaN             NaN          NaN
# 5455233             502.0          BIO             NaN          NaN
# 5455234             665.0          BIO            6.28        793.0
# 5455235              <NA>          NaN            5.68        622.0
# 5455236              <NA>          NaN            5.38        536.0
#
#          year_proceso  puntaje_ranking  puntaje_m2
# 4543791          2023            429.0         351
# 4543792          2023            766.0        <NA>
# 4543793          2023            415.0        <NA>
# 4543794          2023            599.0        <NA>
# 4543795          2023            517.0        <NA>
# ...               ...              ...         ...
# 5455232          2025              NaN        <NA>
# 5455233          2025              NaN        <NA>
# 5455234          2025            856.0         362
# 5455235          2025            631.0        <NA>
# 5455236          2025            536.0         362
#
# [911446 rows x 17 columns]

# %%
df_PSU.loc[:,"%_de_logro_obligatorias"] = round(((df_PSU["puntaje_lectora"] + df_PSU["puntaje_m1"])/ 850)*50, 2)
df_PDT.loc[:,"%_de_logro_obligatorias"] = round(((df_PDT["puntaje_lectora"] + df_PDT["puntaje_m1"])/ 850)*50, 2)
df_PAES.loc[:,"%_de_logro_obligatorias"] = round(((df_PAES["puntaje_lectora"] + df_PAES["puntaje_m1"])/ 1000)*50, 2)
df_PSU["prueba"] = "PSU"
df_PSU["prueba"] = df_PSU["prueba"].astype("category")
df_PDT["prueba"] = "PDT"
df_PDT["prueba"] = df_PDT["prueba"].astype("category")
df_PAES["prueba"] = "PAES"
df_PAES["prueba"] = df_PAES["prueba"].astype("category")
# Out:
# C:\Users\UsuarioCompuElite\AppData\Local\Temp\ipykernel_10840\1182911443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_PSU.loc[:,"%_de_logro_obligatorias"] = round(((df_PSU["puntaje_lectora"] + df_PSU["puntaje_m1"])/ 850)*50, 2)
# C:\Users\UsuarioCompuElite\AppData\Local\Temp\ipykernel_10840\1182911443.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_PDT.loc[:,"%_de_logro_obligatorias"] = round(((df_PDT["puntaje_lectora"] + df_PDT["puntaje_m1"])/ 850)*50, 2)
# C:\Users\UsuarioCompuElite\AppData\Local\Temp\ipykernel_10840\1182911443.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_PAES.loc[:,"%_de_logro_obligatorias"] = round(((df_PAES["puntaje_lectora"] + df_PAES["puntaje_m1"])/ 1000)*50, 2)
# C:\Users\UsuarioCompuElite\AppData\Local\Temp\ipykernel_10840\1182911443.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_PSU["prueba"] = "PSU"
# C:\Users\UsuarioCompuElite\AppData\Local\Temp\ipykernel_10840\1182911443.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_PSU["prueba"] = df_PSU["prueba"].astype("category")
# C:\Users\UsuarioCompuElite\AppData\Local\Temp\ipykernel_10840\1182911443.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_PDT["prueba"] = "PDT"
# C:\Users\UsuarioCompuElite\AppData\Local\Temp\ipykernel_10840\1182911443.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_PDT["prueba"] = df_PDT["prueba"].astype("category")
# C:\Users\UsuarioCompuElite\AppData\Local\Temp\ipykernel_10840\1182911443.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_PAES["prueba"] = "PAES"
# C:\Users\UsuarioCompuElite\AppData\Local\Temp\ipykernel_10840\1182911443.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_PAES["prueba"] = df_PAES["prueba"].astype("category")

# %%
display(df_PSU)
display(df_PDT)
display(df_PAES)
# Out:
#             id_estudiante  id_colegio_rbd       dependencia_colegio  \
# 0         id_001160071115             NaN                 Municipal
# 1        id_0016900171627             NaN                 Municipal
# 2        id_0016900571641             NaN                 Municipal
# 3        id_0028900472899             NaN                 Municipal
# 4         id_004500078456             NaN  Particular Subvencionado
# ...                   ...             ...                       ...
# 4050777  id_9999599479904         24482.0  Particular Subvencionado
# 4050778  id_9999599479967          8618.0  Particular Subvencionado
# 4050779  id_9999599479973         20316.0  Particular Subvencionado
# 4050780  id_9999599479977         14373.0  Particular Subvencionado
# 4050781  id_9999599779976           574.0  Particular Subvencionado
#
#         rama_educacional      situacion_egreso  cod_region  cod_comuna  \
# 0           TP comercial  Act:Nacional-Regular         1.0       201.0
# 1            CH nocturno  Ant:Nacional-Regular         3.0       240.0
# 2           TP comercial  Ant:Nacional-Regular         2.0       225.0
# 3              CH diurno  Act:Nacional-Regular         8.0       415.0
# 4            CH nocturno  Act:Nacional-Regular        10.0       510.0
# ...                  ...                   ...         ...         ...
# 4050777    TP industrial  Act:Nacional-Regular        13.0     13128.0
# 4050778        CH diurno  Act:Nacional-Regular        13.0     13101.0
# 4050779      CH nocturno  Act:Nacional-Regular        16.0     16101.0
# 4050780        CH diurno  Act:Nacional-Regular         5.0      5601.0
# 4050781    TP industrial  Act:Nacional-Regular         4.0      4101.0
#
#          puntaje_lectora  puntaje_m1  puntaje_historia  puntaje_ciencias  \
# 0                  469.0       457.0             437.0             426.0
# 1                  492.0       457.0             513.0              <NA>
# 2                  391.0       442.0              <NA>             396.0
# 3                  353.0       487.0             402.0              <NA>
# 4                  430.0       425.0             451.0              <NA>
# ...                  ...         ...               ...               ...
# 4050777            427.0       498.0             498.0             389.0
# 4050778            559.0       549.0              <NA>             542.0
# 4050779            407.0       415.0             477.0             446.0
# 4050780            380.0       332.0             451.0              <NA>
# 4050781            597.0       506.0             597.0              <NA>
#
#         tipo_ciencia  promedio_notas  puntaje_nem  year_proceso  \
# 0               None            6.30        682.0          2004
# 1               None            5.30        481.0          2004
# 2               None            4.80        376.0          2004
# 3               None            4.80        373.0          2004
# 4               None            5.40        501.0          2004
# ...              ...             ...          ...           ...
# 4050777          TEC            5.13        438.0          2020
# 4050778          QUI            5.80        580.0          2020
# 4050779          QUI            5.30        477.0          2020
# 4050780          NaN            5.20        451.0          2020
# 4050781          NaN            5.48        515.0          2020
#
#          puntaje_ranking  puntaje_m2  %_de_logro_obligatorias prueba
# 0                    NaN        <NA>                    54.47    PSU
# 1                    NaN        <NA>                    55.82    PSU
# 2                    NaN        <NA>                     49.0    PSU
# 3                    NaN        <NA>                    49.41    PSU
# 4                    NaN        <NA>                    50.29    PSU
# ...                  ...         ...                      ...    ...
# 4050777            438.0        <NA>                    54.41    PSU
# 4050778            593.0        <NA>                    65.18    PSU
# 4050779            477.0        <NA>                    48.35    PSU
# 4050780            451.0        <NA>                    41.88    PSU
# 4050781            515.0        <NA>                    64.88    PSU
#
# [4050782 rows x 19 columns]
#             id_estudiante  id_colegio_rbd          dependencia_colegio  \
# 4050782  id_0000900070018         25418.0     Particular Subvencionado
# 4050783  id_0000900470042         25121.0     Particular Subvencionado
# 4050784  id_0000900670095         12730.0     Particular Subvencionado
# 4050785  id_0000900870002          4534.0                    Municipal
# 4050786  id_0001900170136          9534.0     Particular Subvencionado
# ...                   ...             ...                          ...
# 4543786  id_9999599979969          6253.0     Particular Subvencionado
# 4543787  id_9999599979970          6163.0                    Municipal
# 4543788  id_9999599979971          6163.0                    Municipal
# 4543789  id_9999599979986          6398.0  Servicio Local de Educación
# 4543790  id_9999599979998          9332.0     Particular Subvencionado
#
#                rama_educacional      situacion_egreso  cod_region  cod_comuna  \
# 4050782  TP servicios y técnica  Ant:Nacional-Regular        13.0     13401.0
# 4050783               CH diurno  Ant:Nacional-Regular        13.0     13301.0
# 4050784           TP industrial  Act:Nacional-Regular         1.0      1107.0
# 4050785            TP comercial  Ant:Nacional-Regular         8.0      8101.0
# 4050786               CH diurno  Ant:Nacional-Regular        13.0     13110.0
# ...                         ...                   ...         ...         ...
# 4543786               CH diurno  Act:Nacional-Regular         9.0      9114.0
# 4543787            TP comercial  Ant:Nacional-Regular         9.0      9105.0
# 4543788  TP servicios y técnica  Ant:Nacional-Regular         9.0      9105.0
# 4543789               CH diurno  Act:Nacional-Regular         9.0      9117.0
# 4543790               CH diurno  Act:Nacional-Regular        13.0     13110.0
#
#          puntaje_lectora  puntaje_m1  puntaje_historia  puntaje_ciencias  \
# 4050782            693.0       509.0             716.0             617.0
# 4050783            505.0       419.0             505.0              <NA>
# 4050784            214.0       405.0             360.0              <NA>
# 4050785            495.0       302.0              <NA>             365.0
# 4050786            764.0       614.0              <NA>             686.0
# ...                  ...         ...               ...               ...
# 4543786            600.0       555.0             538.0             569.0
# 4543787            507.0       310.0              <NA>             503.0
# 4543788            463.0       434.0              <NA>             455.0
# 4543789            235.0       278.0             350.0             314.0
# 4543790            279.0       409.0             405.0              <NA>
#
#         tipo_ciencia  promedio_notas  puntaje_nem  year_proceso  \
# 4050782          TEC            6.00        625.0          2021
# 4050783          NaN            5.35        483.0          2021
# 4050784          NaN            5.07        421.0          2021
# 4050785          TEC            5.60        539.0          2021
# 4050786          QUI            6.30        689.0          2021
# ...              ...             ...          ...           ...
# 4543786          BIO            5.63        545.0          2022
# 4543787          BIO            5.28        468.0          2022
# 4543788          TEC            6.30        692.0          2022
# 4543789          BIO            4.85        363.0          2022
# 4543790          NaN            5.25        459.0          2022
#
#          puntaje_ranking  puntaje_m2  %_de_logro_obligatorias prueba
# 4050782            713.0        <NA>                    70.71    PDT
# 4050783            484.0        <NA>                    54.35    PDT
# 4050784            421.0        <NA>                    36.41    PDT
# 4050785            539.0        <NA>                    46.88    PDT
# 4050786            757.0        <NA>                    81.06    PDT
# ...                  ...         ...                      ...    ...
# 4543786            548.0        <NA>                    67.94    PDT
# 4543787            469.0        <NA>                    48.06    PDT
# 4543788            813.0        <NA>                    52.76    PDT
# 4543789            363.0        <NA>                    30.18    PDT
# 4543790            459.0        <NA>                    40.47    PDT
#
# [493009 rows x 19 columns]
#             id_estudiante  id_colegio_rbd          dependencia_colegio  \
# 4543791  id_0000900170003         10584.0                    Municipal
# 4543792  id_0000900470024         10250.0                    Municipal
# 4543793  id_0000900670068         12667.0     Particular Subvencionado
# 4543794  id_0001900070103          7006.0     Particular Subvencionado
# 4543795  id_0001900070149          6752.0                    Municipal
# ...                   ...             ...                          ...
# 5455232  id_5995599440825          9986.0                    Municipal
# 5455233  id_4895488246247             NaN                          NaN
# 5455234  id_9866988747313          9140.0     Particular Subvencionado
# 5455235  id_5866598447255          2733.0                    Municipal
# 5455236  id_7666786545377           125.0  Servicio Local de Educación
#
#                         rama_educacional      situacion_egreso  cod_region  \
# 4543791                      CH nocturno  Ant:Nacional-Regular        13.0
# 4543792                      CH nocturno  Act:Nacional-Regular        13.0
# 4543793                        CH diurno  Ant:Nacional-Regular         1.0
# 4543794                        CH diurno  Ant:Nacional-Regular        14.0
# 4543795           TP servicios y técnica  Ant:Nacional-Regular        14.0
# ...                                  ...                   ...         ...
# 5455232                     TP comercial  Act:Nacional-Regular        13.0
# 5455233  CH - reconocimiento de estudios        Act:Extranjero         NaN
# 5455234                        CH diurno  Ant:Nacional-Regular        13.0
# 5455235                        CH diurno  Ant:Nacional-Regular         7.0
# 5455236                        CH diurno  Ant:Nacional-Regular         1.0
#
#          cod_comuna  puntaje_lectora  puntaje_m1  puntaje_historia  \
# 4543791     13401.0             <NA>       402.0             423.0
# 4543792     13107.0            475.0        <NA>              <NA>
# 4543793      1101.0            536.0       413.0             489.0
# 4543794     14202.0            589.0       437.0              <NA>
# 4543795     14101.0             <NA>        <NA>              <NA>
# ...             ...              ...         ...               ...
# 5455232     13126.0             <NA>        <NA>              <NA>
# 5455233         NaN            605.0       700.0             542.0
# 5455234     13122.0            746.0       589.0              <NA>
# 5455235      7301.0             <NA>        <NA>              <NA>
# 5455236      1101.0            596.0       710.0              <NA>
#
#          puntaje_ciencias tipo_ciencia  promedio_notas  puntaje_nem  \
# 4543791              <NA>          NaN            5.03        429.0
# 4543792              <NA>          NaN            5.90        689.0
# 4543793              <NA>          NaN            5.00        415.0
# 4543794             478.0          BIO            5.60        599.0
# 4543795              <NA>          NaN            5.28        506.0
# ...                   ...          ...             ...          ...
# 5455232              <NA>          NaN             NaN          NaN
# 5455233             502.0          BIO             NaN          NaN
# 5455234             665.0          BIO            6.28        793.0
# 5455235              <NA>          NaN            5.68        622.0
# 5455236              <NA>          NaN            5.38        536.0
#
#          year_proceso  puntaje_ranking  puntaje_m2  %_de_logro_obligatorias  \
# 4543791          2023            429.0         351                     <NA>
# 4543792          2023            766.0        <NA>                     <NA>
# 4543793          2023            415.0        <NA>                    47.45
# 4543794          2023            599.0        <NA>                     51.3
# 4543795          2023            517.0        <NA>                     <NA>
# ...               ...              ...         ...                      ...
# 5455232          2025              NaN        <NA>                     <NA>
# 5455233          2025              NaN        <NA>                    65.25
# 5455234          2025            856.0         362                    66.75
# 5455235          2025            631.0        <NA>                     <NA>
# 5455236          2025            536.0         362                     65.3
#
#         prueba
# 4543791   PAES
# 4543792   PAES
# 4543793   PAES
# 4543794   PAES
# 4543795   PAES
# ...        ...
# 5455232   PAES
# 5455233   PAES
# 5455234   PAES
# 5455235   PAES
# 5455236   PAES
#
# [911446 rows x 19 columns]

# %%
lista = [df_PSU.sample(4000), df_PDT.sample(400), df_PAES.sample(450)]

df_random = pd.concat(lista).reset_index(drop=True)

plt.figure(figsize=(10, 8))

sns.scatterplot(data=df_random, x="%_de_logro_obligatorias", y="promedio_notas",hue="prueba",style="prueba")

plt.title("Relacion Promedio Notas y Pruebas obligatorias")
plt.xlabel("Logro Obligatorias")
plt.ylabel("Promedio Notas")
plt.show()

# %%
lista = [df_PSU, df_PDT, df_PAES]

df_final = pd.concat(lista).reset_index(drop=True)

# %%
df_final.to_parquet("../data/datos_procesados.parquet", engine="pyarrow", index=False)

# %%
columnas_numericas = [
    'promedio_notas', 'puntaje_nem', 'puntaje_ranking',
    'puntaje_lectora', 'puntaje_m1', 'puntaje_m2',
    'puntaje_historia', 'puntaje_ciencias',"%_de_logro_obligatorias"]

matriz_corr = df_final[columnas_numericas].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(matriz_corr, annot=True, fmt='.2f', cmap='coolwarm_r')
plt.title('Mapa de Correlación entre Notas y Puntajes')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
plt.figure(figsize=(12, 8))

order_logro = df_final.groupby('dependencia_colegio')['%_de_logro_obligatorias'].median().sort_values(ascending=False).index

sns.boxplot(
    data=df_final,
    x='%_de_logro_obligatorias',
    y='dependencia_colegio',
    order=order_logro,
    showfliers=False
)

plt.title('Distribución del % de Logro en Pruebas Obligatorias por Dependencia', fontsize=16)
plt.xlabel('% de Logro (Lectora y M1)')
plt.ylabel('Tipo de Dependencia')
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter('{:.0f}%'.format))
plt.show()

# %%
plt.figure(figsize=(12, 7))
sns.violinplot(
    data=df_final, 
    y='puntaje_m1', 
    x='rama_educacional',
    order=df.groupby('rama_educacional')['puntaje_m1'].median().sort_values(ascending=False).index
)
plt.title('Distribución de Puntaje M1 por Rama Educacional')
plt.ylabel('Puntaje Matemática M1')
plt.xlabel('Rama Educacional')
plt.xticks(rotation=45, ha='right')
plt.show()
